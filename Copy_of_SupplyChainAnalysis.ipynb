# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhini99/supply-chain-analysis-powerbi-visualization-/blob/main/Copy_of_SupplyChainAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from tabulate import tabulate

# %%
data_df = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/DataCoSupplyChainDataset.csv", encoding='latin-1')
display(data_df)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
# List all columns in the original CSV file
all_columns = data_df.columns.tolist()
print("All Columns in the Original CSV File:")
for index, column in enumerate(all_columns, start=1):
    print(f"{index}. {column}")
# Out:
# All Columns in the Original CSV File:
# 1. Type
# 2. Days for shipping (real)
# 3. Days for shipment (scheduled)
# 4. Benefit per order
# 5. Sales per customer
# 6. Delivery Status
# 7. Late_delivery_risk
# 8. Category Id
# 9. Category Name
# 10. Customer City
# 11. Customer Country
# 12. Customer Email
# 13. Customer Fname
# 14. Customer Id
# 15. Customer Lname
# 16. Customer Password
# 17. Customer Segment
# 18. Customer State
# 19. Customer Street
# 20. Customer Zipcode
# 21. Department Id
# 22. Department Name
# 23. Latitude
# 24. Longitude
# 25. Market
# 26. Order City
# 27. Order Country
# 28. Order Customer Id
# 29. order date (DateOrders)
# 30. Order Id
# 31. Order Item Cardprod Id
# 32. Order Item Discount
# 33. Order Item Discount Rate
# 34. Order Item Id
# 35. Order Item Product Price
# 36. Order Item Profit Ratio
# 37. Order Item Quantity
# 38. Sales
# 39. Order Item Total
# 40. Order Profit Per Order
# 41. Order Region
# 42. Order State
# 43. Order Status
# ...

# %%
# Format the list in a table
columns_table = [{"Index": index, "Column Name": column} for index, column in enumerate(all_columns, start=1)]

# Print the table
print("All Columns in the Original CSV file:")
print(tabulate(columns_table, headers="keys", tablefmt="grid"))
# Out:
# All Columns in the Original CSV file:
# +---------+-------------------------------+
# |   Index | Column Name                   |
# +=========+===============================+
# |       1 | Type                          |
# +---------+-------------------------------+
# |       2 | Days for shipping (real)      |
# +---------+-------------------------------+
# |       3 | Days for shipment (scheduled) |
# +---------+-------------------------------+
# |       4 | Benefit per order             |
# +---------+-------------------------------+
# |       5 | Sales per customer            |
# +---------+-------------------------------+
# |       6 | Delivery Status               |
# +---------+-------------------------------+
# |       7 | Late_delivery_risk            |
# +---------+-------------------------------+
# |       8 | Category Id                   |
# +---------+-------------------------------+
# |       9 | Category Name                 |
# ...

# %%
data_df.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Email                    object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Password                 object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# ...

# %%
#Look at your missing data
missing_data = data_df.isnull()
missing_data.head()
# Out:
#     Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0  False                     False                          False
# 1  False                     False                          False
# 2  False                     False                          False
# 3  False                     False                          False
# 4  False                     False                          False
#
#    Benefit per order  Sales per customer  Delivery Status  Late_delivery_risk  \
# 0              False               False            False               False
# 1              False               False            False               False
# 2              False               False            False               False
# 3              False               False            False               False
# 4              False               False            False               False
#
#    Category Id  Category Name  Customer City  ...  Order Zipcode  \
# ...

# %% [markdown]
# **Create Separate Dataframes for Each Table**
#
# **Tables**
#
# 1. Orders
# 2. OrderItems
# 3. Customers
# 4. Products
# 5. Categories
# 6. Department

# %%
# Orders Table
orders_columns = ['Order Id', 'Order Customer Id', 'order date (DateOrders)', 'Order Status', 'Order Profit Per Order', 'Market', 'Order City', 'Order State', 'Order Country', 'Order Region', 'shipping date (DateOrders)']
orders_df = data_df[orders_columns]
display(orders_df)
# Out:
#         Order Id  Order Customer Id order date (DateOrders)     Order Status  \
# 0          77202              20755         1/31/2018 22:56         COMPLETE
# 1          75939              19492         1/13/2018 12:27          PENDING
# 2          75938              19491         1/13/2018 12:06           CLOSED
# 3          75937              19490         1/13/2018 11:45         COMPLETE
# 4          75936              19489         1/13/2018 11:24  PENDING_PAYMENT
# ...          ...                ...                     ...              ...
# 180514     26043               1005          1/16/2016 3:40           CLOSED
# 180515     26037               9141          1/16/2016 1:34         COMPLETE
# 180516     26024                291         1/15/2016 21:00          PENDING
# 180517     26022               2813         1/15/2016 20:18  PENDING_PAYMENT
# 180518     26018               7547         1/15/2016 18:54  PENDING_PAYMENT
#
# ...

# %%
# Change the data type of columns Shipping Date into date
orders_df['shipping date (DateOrders)'] = pd.to_datetime(orders_df['shipping date (DateOrders)'], infer_datetime_format=True)
orders_df['Shipping Date'] = orders_df['shipping date (DateOrders)'].dt.strftime('%Y-%m-%d')

display(orders_df)
# Out:
# <ipython-input-9-bcac3d8b3570>:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   orders_df['shipping date (DateOrders)'] = pd.to_datetime(orders_df['shipping date (DateOrders)'], infer_datetime_format=True)
# <ipython-input-9-bcac3d8b3570>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_df['shipping date (DateOrders)'] = pd.to_datetime(orders_df['shipping date (DateOrders)'], infer_datetime_format=True)
# <ipython-input-9-bcac3d8b3570>:3: SettingWithCopyWarning:
# ...

# %%
# Change the data type of columns Order Date into date
orders_df['order date (DateOrders)'] = pd.to_datetime(orders_df['order date (DateOrders)'], infer_datetime_format=True)
orders_df['Order Date'] = orders_df['order date (DateOrders)'].dt.strftime('%Y-%m-%d')

display(orders_df)
# Out:
# <ipython-input-10-547da3c54656>:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   orders_df['order date (DateOrders)'] = pd.to_datetime(orders_df['order date (DateOrders)'], infer_datetime_format=True)
# <ipython-input-10-547da3c54656>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_df['order date (DateOrders)'] = pd.to_datetime(orders_df['order date (DateOrders)'], infer_datetime_format=True)
# <ipython-input-10-547da3c54656>:3: SettingWithCopyWarning:
# ...

# %%
# OrderItems Table
order_items_columns = ['Order Item Id', 'Order Id', 'Product Card Id', 'Order Item Cardprod Id', 'Order Item Discount', 'Order Item Discount Rate', 'Order Item Product Price', 'Order Item Profit Ratio', 'Order Item Quantity', 'Order Item Total', 'Sales per customer', 'Order Profit Per Order']
order_items_df = data_df[order_items_columns]
display(order_items_df)
# Out:
#         Order Item Id  Order Id  Product Card Id  Order Item Cardprod Id  \
# 0              180517     77202             1360                    1360
# 1              179254     75939             1360                    1360
# 2              179253     75938             1360                    1360
# 3              179252     75937             1360                    1360
# 4              179251     75936             1360                    1360
# ...               ...       ...              ...                     ...
# 180514          65177     26043             1004                    1004
# 180515          65161     26037             1004                    1004
# 180516          65129     26024             1004                    1004
# 180517          65126     26022             1004                    1004
# 180518          65113     26018             1004                    1004
#
#         Order Item Discount  Order Item Discount Rate  \
# ...

# %%
# Customers Table
customers_columns = ['Customer Id', 'Customer Fname', 'Customer Lname', 'Customer Email', 'Customer Password', 'Customer Segment', 'Customer City', 'Customer State', 'Customer Country', 'Customer Street', 'Customer Zipcode', 'Latitude', 'Longitude']
customers_df = data_df[customers_columns]
display(customers_df)
# Out:
#         Customer Id Customer Fname Customer Lname Customer Email  \
# 0             20755          Cally       Holloway      XXXXXXXXX
# 1             19492          Irene           Luna      XXXXXXXXX
# 2             19491        Gillian      Maldonado      XXXXXXXXX
# 3             19490           Tana           Tate      XXXXXXXXX
# 4             19489           Orli      Hendricks      XXXXXXXXX
# ...             ...            ...            ...            ...
# 180514         1005          Maria       Peterson      XXXXXXXXX
# 180515         9141         Ronald          Clark      XXXXXXXXX
# 180516          291           John          Smith      XXXXXXXXX
# 180517         2813           Mary          Smith      XXXXXXXXX
# 180518         7547         Andrea         Ortega      XXXXXXXXX
#
#        Customer Password Customer Segment Customer City Customer State  \
# 0              XXXXXXXXX         Consumer        Caguas             PR
# ...

# %%
# Products Table
products_columns = ['Product Card Id', 'Product Category Id', 'Product Name', 'Product Description', 'Product Image', 'Product Price', 'Product Status']
products_df = data_df[products_columns]
display(products_df)
# Out:
#         Product Card Id  Product Category Id  \
# 0                  1360                   73
# 1                  1360                   73
# 2                  1360                   73
# 3                  1360                   73
# 4                  1360                   73
# ...                 ...                  ...
# 180514             1004                   45
# 180515             1004                   45
# 180516             1004                   45
# 180517             1004                   45
# 180518             1004                   45
#
#                                      Product Name  Product Description  \
# 0                                    Smart watch                   NaN
# 1                                    Smart watch                   NaN
# 2                                    Smart watch                   NaN
# 3                                    Smart watch                   NaN
# ...

# %%
# Categories Table
categories_columns = ['Category Id', 'Category Name']
categories_df = data_df[categories_columns]
display(categories_df)
# Out:
#         Category Id   Category Name
# 0                73  Sporting Goods
# 1                73  Sporting Goods
# 2                73  Sporting Goods
# 3                73  Sporting Goods
# 4                73  Sporting Goods
# ...             ...             ...
# 180514           45         Fishing
# 180515           45         Fishing
# 180516           45         Fishing
# 180517           45         Fishing
# 180518           45         Fishing
#
# [180519 rows x 2 columns]

# %%
# Departments Table
departments_columns = ['Department Id', 'Department Name']
departments_df = data_df[departments_columns]
display(departments_df)
# Out:
#         Department Id Department Name
# 0                   2         Fitness
# 1                   2         Fitness
# 2                   2         Fitness
# 3                   2         Fitness
# 4                   2         Fitness
# ...               ...             ...
# 180514              7        Fan Shop
# 180515              7        Fan Shop
# 180516              7        Fan Shop
# 180517              7        Fan Shop
# 180518              7        Fan Shop
#
# [180519 rows x 2 columns]

# %%
# OrdersProcessing Table
ordersprocessing_columns = ['Order Id', 'Type', 'Days for shipping (real)', 'Days for shipment (scheduled)', 'Benefit per order', 'Shipping Mode', 'Delivery Status', 'Order Status', 'Late_delivery_risk']
ordersprocessing_df = data_df[ordersprocessing_columns]
display(ordersprocessing_df)
# Out:
#         Order Id      Type  Days for shipping (real)  \
# 0          77202     DEBIT                         3
# 1          75939  TRANSFER                         5
# 2          75938      CASH                         4
# 3          75937     DEBIT                         3
# 4          75936   PAYMENT                         2
# ...          ...       ...                       ...
# 180514     26043      CASH                         4
# 180515     26037     DEBIT                         3
# 180516     26024  TRANSFER                         5
# 180517     26022   PAYMENT                         3
# 180518     26018   PAYMENT                         4
#
#         Days for shipment (scheduled)  Benefit per order   Shipping Mode  \
# 0                                   4          91.250000  Standard Class
# 1                                   4        -249.089996  Standard Class
# 2                                   4        -247.779999  Standard Class
# ...

# %%
# Replace 'output_path' with the desired output directory
output_path = 'C:\\Users\\LENOVO\\Documents\\Personal Project\\Data Analysis on DataCo Supply Chain Management System'

# Save each DataFrame to a separate CSV file
orders_df.to_csv('orders.csv', index=False)
order_items_df.to_csv('order_items.csv', index=False)
customers_df.to_csv('customers.csv', index=False)
products_df.to_csv('products.csv', index=False)
categories_df.to_csv('categories.csv', index=False)
departments_df.to_csv('departments.csv', index=False)
